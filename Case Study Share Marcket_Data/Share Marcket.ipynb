# %%
# %pip install yfinance

# %%
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf

# %%
# Load Real Stock Data
# Reliance Industries Limited (RELIANCE.NS)

df  = yf.download("RELIANCE.NS",start="2025-01-01",end="2026-01-01")
df.head()

# Save The Data

# df.to_csv("Reliance.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2025-01-01  1210.793579  1215.800389  1201.226179  1204.448352     5892590
# 2025-01-02  1231.167725  1233.794938  1209.554328  1210.793626    15486276
# 2025-01-03  1240.437744  1251.244443  1224.921714  1233.249818    15521102
# 2025-01-06  1207.571411  1251.194681  1204.597097  1243.213557    14816766
# 2025-01-07  1230.225708  1233.844481  1210.793549  1211.537128    10070505

# %%
df.columns
# Out:
# MultiIndex([( 'Close', 'RELIANCE.NS'),
#             (  'High', 'RELIANCE.NS'),
#             (   'Low', 'RELIANCE.NS'),
#             (  'Open', 'RELIANCE.NS'),
#             ('Volume', 'RELIANCE.NS')],
#            names=['Price', 'Ticker'])

# %%
# Claosing Price Trend
plt.figure(figsize=(12,5))
plt.plot(df["Close"])
plt.title("Reliance Closing Price")
plt.xlabel("Date")
plt.ylabel("Price (inr)")
plt.grid(True)
plt.show()

# %%
# Opeaning Price Trend

plt.figure(figsize=(12,5))
plt.plot(df["Open"])
plt.title("Reliance Opeaning Price")
plt.xlabel("Date")
plt.ylabel("Price (inr)")
plt.grid(True)
plt.show()

# %%
# Trade Analysis 50 Days

df["MA50"] =df["Close"].rolling(window=50).mean()

# %%
df.head()
# Out:
# Price             Close         High          Low         Open      Volume  \
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2025-01-01  1210.793579  1215.800389  1201.226179  1204.448352     5892590
# 2025-01-02  1231.167725  1233.794938  1209.554328  1210.793626    15486276
# 2025-01-03  1240.437744  1251.244443  1224.921714  1233.249818    15521102
# 2025-01-06  1207.571411  1251.194681  1204.597097  1243.213557    14816766
# 2025-01-07  1230.225708  1233.844481  1210.793549  1211.537128    10070505
#
# Price      MA50
# Ticker
# Date
# 2025-01-01  NaN
# 2025-01-02  NaN
# 2025-01-03  NaN
# 2025-01-06  NaN
# 2025-01-07  NaN

# %%
# Trade Chart

plt.figure(figsize=(12,5))
plt.plot(df["Close"],label="Closing Price")
plt.plot(df["MA50"],label="50 Days Moving Avg")
plt.title("Reliance Closing Price")
plt.xlabel("Date")
plt.ylabel("Price (inr)")
plt.grid(True)
plt.legend()
plt.show()

# %%
# High Vs Low Price

plt.figure(figsize=(12,5))
plt.plot(df["High"],label="High Price")
plt.plot(df["Low"],label="Low Price")
plt.title("High Vs Low Price")
plt.xlabel("Date")
plt.ylabel("Price (inr)")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Trade Analysis 100 Days

df["MA100"] =df["Close"].rolling(window=100).mean()

# %%
plt.figure(figsize=(12,5))
plt.plot(df["Close"],label="Closing Price")
plt.plot(df["MA50"],label="50 Days Moving Avg")
plt.plot(df["MA100"],label="100 Days Moving Avg")
plt.title("Reliance Closing Price")
plt.xlabel("Date")
plt.ylabel("Price (inr)")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Bar Chart Volume

plt.figure(figsize=(12,5))

plt.bar(df.index, df[("Volume", "RELIANCE.NS")])

plt.title("Trading Volume")
plt.xlabel("Date")
plt.ylabel("Volume")

plt.show()

# %%
# %pip install mplfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.columns= df.columns.droplevel(1)

# %%
df = df.astype({
    "Open": float,
    "High": float,
    "Low": float,
    "Close": float,
    "Volume": int
})

# %%
df.dtypes
# Out:
# Price
# Close     float64
# High      float64
# Low       float64
# Open      float64
# Volume      int64
# MA50      float64
# MA100     float64
# dtype: object

# %%
import mplfinance as mpf

mpf.plot(
    df,
    type="candle",
    volume=True,
    style="yahoo",
    figsize=(14,8),
    title="Reliance Stock Price"
)

# %%
# Box Plot

plt.figure(figsize=(8,5))

plt.boxplot(df["Close"])

plt.title("Box Plot of Closing Price")

plt.show()

# %%
df = yf.download(
    ["RELIANCE.NS", "TCS.NS"],
    start="2023-01-01",
    end="2024-01-01"
)

plt.figure(figsize=(12,6))

plt.plot(df["Close"]["RELIANCE.NS"], label="Reliance")
plt.plot(df["Close"]["TCS.NS"], label="TCS")

plt.title("Reliance vs TCS Closing Price")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed
